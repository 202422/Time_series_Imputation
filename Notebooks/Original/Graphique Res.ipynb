# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import statistics
import math

df = pd.read_csv(f'drive/MyDrive/All patients/Resultats/Patient_result_SVR_20.csv')
df.describe()
# Out:
#               MAE        RMSE        MMRE        PRED
# count  102.000000  102.000000  102.000000  102.000000
# mean    43.996318   43.996318   30.241054   59.918333
# std     43.314203   43.314203   35.983811    6.656438
# min      0.050326    0.050326    0.012581   51.428571
# 25%     11.766125   11.766125    8.220750   57.394489
# 50%     30.724654   30.724654   16.924969   59.312180
# 75%     56.885949   56.885949   37.040637   60.778109
# max    193.952296  193.952296  208.849443  100.000000

# %%
print(statistics.median(df["PRED"]))
# Out:
# 59.312179739850215

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as pyplot



pyplot.plot([5,10,20,30,40,50], [11.36, 15.27, 25.67, 24.56, 27.43, 29.89],label="LSTM", color='g', marker='o', markerfacecolor='g', markeredgecolor='g', markersize=8)
pyplot.plot([5,10,20,30,40,50], [9.93, 12.28, 18.56, 18.92, 20.17, 16.82] ,label="CNN",color='r', marker='o', markerfacecolor='r', markeredgecolor='r', markersize=8)
pyplot.plot([5,10,20,30,40,50], [8.26, 10.46, 15.90, 21.98, 24.35, 28.44] ,label="GRU",color='b', marker='o', markerfacecolor='b', markeredgecolor='b', markersize=8)
pyplot.plot([5,10,20,30,40,50], [34.54, 32.32, 30.72, 29.68, 28.55, 16.33] ,label="SVR",color='y', marker='o', markerfacecolor='y', markeredgecolor='y', markersize=8)
pyplot.plot([5,10,20,30,40,50], [43.26, 38.33, 34.04, 31.84, 27.09, 24.52] ,label="RNN",color='c', marker='o', markerfacecolor='c', markeredgecolor='c', markersize=8)
# pyplot.axis([5,10,20,30,40,50])
pyplot.xlabel('Percentage %')
pyplot.title('RMSE')
pyplot.legend()
# Display grid
pyplot.grid(True)
# Print the chart
pyplot.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as pyplot



pyplot.plot([5,10,20,30,40,50], [11.36, 15.27, 25.67, 24.56, 27.43, 29.89],label="LSTM", color='g', marker='o', markerfacecolor='g', markeredgecolor='g', markersize=8)
pyplot.plot([5,10,20,30,40,50], [9.93, 12.28, 18.56, 18.92, 20.17, 16.82] ,label="CNN",color='r', marker='o', markerfacecolor='r', markeredgecolor='r', markersize=8)
pyplot.plot([5,10,20,30,40,50], [8.26, 10.46, 15.90, 21.98, 24.35, 28.44] ,label="GRU",color='b', marker='o', markerfacecolor='b', markeredgecolor='b', markersize=8)
pyplot.plot([5,10,20,30,40,50], [34.54, 32.32, 30.72, 29.68, 28.55, 16.33] ,label="SVR",color='y', marker='o', markerfacecolor='y', markeredgecolor='y', markersize=8)
pyplot.plot([5,10,20,30,40,50], [43.26, 38.33, 34.04, 31.84, 27.09, 24.52] ,label="RNN",color='c', marker='o', markerfacecolor='c', markeredgecolor='c', markersize=8)
# pyplot.axis([5,10,20,30,40,50])
pyplot.xlabel('Percentage %')
pyplot.title('MAE')
pyplot.legend()
# Display grid
pyplot.grid(True)
# Print the chart
pyplot.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as pyplot



pyplot.plot([5,10,20,30,40,50], [19.38, 10.42, 15.46, 17.54, 18.2, 19],label="LSTM", color='g', marker='o', markerfacecolor='g', markeredgecolor='g', markersize=8)
pyplot.plot([5,10,20,30,40,50], [11.38, 9.40, 9.91, 10.44, 12.52, 11.59] ,label="CNN",color='r', marker='o', markerfacecolor='r', markeredgecolor='r', markersize=8)
pyplot.plot([5,10,20,30,40,50], [13.53, 6.05, 9.64, 11.23, 13.2, 15] ,label="GRU",color='b', marker='o', markerfacecolor='b', markeredgecolor='b', markersize=8)
pyplot.plot([5,10,20,30,40,50], [38.67, 21.24, 16.92, 17.26, 14.63, 9.52] ,label="SVR",color='y', marker='o', markerfacecolor='y', markeredgecolor='y', markersize=8)
pyplot.plot([5,10,20,30,40,50], [26.65, 24.72, 25.74, 25.03, 24.46, 26.32] ,label="RNN",color='c', marker='o', markerfacecolor='c', markeredgecolor='c', markersize=8)
# pyplot.axis([5,10,20,30,40,50])
pyplot.xlabel('Percentage %')
pyplot.title('MMRE')
pyplot.legend()
# Display grid
pyplot.grid(True)
# Print the chart
pyplot.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as pyplot



pyplot.plot([5,10,20,30,40,50], [81.76, 80, 62.20, 66.66, 56.42, 48.30],label="LSTM", color='g', marker='o', markerfacecolor='g', markeredgecolor='g', markersize=8)
pyplot.plot([5,10,20,30,40,50], [95.26, 81.89, 83.33, 84.29, 83.33, 73.33] ,label="CNN",color='r', marker='o', markerfacecolor='r', markeredgecolor='r', markersize=8)
pyplot.plot([5,10,20,30,40,50], [84.02, 83.33, 75, 75, 72, 68] ,label="GRU",color='b', marker='o', markerfacecolor='b', markeredgecolor='b', markersize=8)
pyplot.plot([5,10,20,30,40,50], [59.31, 56.77, 59.31, 60, 68.42, 70.06] ,label="SVR",color='y', marker='o', markerfacecolor='y', markeredgecolor='y', markersize=8)
pyplot.plot([5,10,20,30,40,50], [48.93, 54.90, 55.57, 56.22, 58.88, 62.52] ,label="RNN",color='c', marker='o', markerfacecolor='c', markeredgecolor='c', markersize=8)
# pyplot.axis([5,10,20,30,40,50])
pyplot.xlabel('Percentage %')
pyplot.title('PRED')
pyplot.legend()
# Display grid
pyplot.grid(True)
# Print the chart
pyplot.show()
